# %% [markdown]
# # Exploración del SDK de Python
#
# ## Instalación del SDK para Python
# Para instalar el SDK de Python en el entorno de Python, necesita Python 3.7 o posterior. Puede instalar el paquete con pip:

# %%
pip install azure-ai-ml
# Out:
# Collecting azure-ai-ml
#   Downloading azure_ai_ml-1.9.0-py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 39.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from azure-ai-ml) (6.0)
# Collecting msrest>=0.6.18 (from azure-ai-ml)
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 3.6 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-ai-ml)
#   Downloading azure_core-1.29.1-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 7.7 MB/s eta 0:00:00
# Collecting azure-mgmt-core<2.0.0,>=1.3.0 (from azure-ai-ml)
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Collecting marshmallow<4.0.0,>=3.5 (from azure-ai-ml)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from azure-ai-ml) (4.18.0)
# Collecting tqdm<5.0.0 (from azure-ai-ml)
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 3.8 MB/s eta 0:00:00
# Collecting strictyaml<2.0.0 (from azure-ai-ml)
#   Downloading strictyaml-1.7.3-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama<0.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from azure-ai-ml) (0.4.6)
# Collecting pyjwt<3.0.0 (from azure-ai-ml)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting azure-storage-blob<13.0.0,>=12.10.0 (from azure-ai-ml)
#   Downloading azure_storage_blob-12.17.0-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 15.4 MB/s eta 0:00:00
# Collecting azure-storage-file-share<13.0.0 (from azure-ai-ml)
#   Downloading azure_storage_file_share-12.13.0-py3-none-any.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 6.2 MB/s eta 0:00:00a 0:00:01
# Collecting azure-storage-file-datalake<13.0.0 (from azure-ai-ml)
#   Downloading azure_storage_file_datalake-12.12.0-py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.8/247.8 kB 11.2 MB/s eta 0:00:00
# Collecting pydash<6.0.0 (from azure-ai-ml)
#   Downloading pydash-5.1.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 3.9 MB/s eta 0:00:00
# Collecting isodate (from azure-ai-ml)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.8 MB/s eta 0:00:00
# Collecting azure-common<2.0.0,>=1.1 (from azure-ai-ml)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions<5.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from azure-ai-ml) (4.7.1)
# Collecting opencensus-ext-azure<2.0.0 (from azure-ai-ml)
#   Downloading opencensus_ext_azure-1.1.9-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /home/codespace/.local/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-ml) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /home/codespace/.local/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-ml) (1.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in /home/codespace/.local/lib/python3.10/site-packages (from azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml) (41.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (2023.6.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.29.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.8.8)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml) (23.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from msrest>=0.6.18->azure-ai-ml) (2023.5.7)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.18->azure-ai-ml)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting azure-identity<2.0.0,>=1.5.0 (from opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading azure_identity-1.14.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 kB 7.6 MB/s eta 0:00:00
# Collecting opencensus<1.0.0,>=0.11.2 (from opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.6.3 in /home/codespace/.local/lib/python3.10/site-packages (from opencensus-ext-azure<2.0.0->azure-ai-ml) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from strictyaml<2.0.0->azure-ai-ml) (2.8.2)
# Collecting msal<2.0.0,>=1.20.0 (from azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading msal-1.23.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 4.2 MB/s eta 0:00:00
# Collecting msal-extensions<2.0.0,>=0.3.0 (from azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml) (1.15.1)
# Collecting opencensus-context>=0.1.3 (from opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml) (2.0.3)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml) (2.21)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 11.1 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading protobuf-4.24.0-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 13.6 MB/s eta 0:00:00
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 8.9 MB/s eta 0:00:00
# Collecting portalocker<3,>=1.0 (from msal-extensions<2.0.0,>=0.3.0->azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 9.2 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 6.5 MB/s eta 0:00:00
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.2->opencensus-ext-azure<2.0.0->azure-ai-ml)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: opencensus-context, azure-common, urllib3, tqdm, pyjwt, pydash, pyasn1, protobuf, portalocker, oauthlib, marshmallow, isodate, cachetools, strictyaml, rsa, pyasn1-modules, googleapis-common-protos, requests-oauthlib, google-auth, azure-core, msrest, msal, google-api-core, azure-storage-file-share, azure-storage-blob, azure-mgmt-core, opencensus, msal-extensions, azure-storage-file-datalake, azure-identity, opencensus-ext-azure, azure-ai-ml
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.3
#     Uninstalling urllib3-2.0.3:
#       Successfully uninstalled urllib3-2.0.3
# Successfully installed azure-ai-ml-1.9.0 azure-common-1.1.28 azure-core-1.29.1 azure-identity-1.14.0 azure-mgmt-core-1.4.0 azure-storage-blob-12.17.0 azure-storage-file-datalake-12.12.0 azure-storage-file-share-12.13.0 cachetools-5.3.1 google-api-core-2.11.1 google-auth-2.22.0 googleapis-common-protos-1.60.0 isodate-0.6.1 marshmallow-3.20.1 msal-1.23.0 msal-extensions-1.0.0 msrest-0.7.1 oauthlib-3.2.2 opencensus-0.11.2 opencensus-context-0.1.3 opencensus-ext-azure-1.1.9 portalocker-2.7.0 protobuf-4.24.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 pydash-5.1.2 pyjwt-2.8.0 requests-oauthlib-1.3.1 rsa-4.9 strictyaml-1.7.3 tqdm-4.66.1 urllib3-1.26.16
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Conexión a un área de trabajo
# Una vez instalado el SDK de Python, deberá conectarse al área de trabajo. Al conectarse, va a autenticar el entorno para interactuar con el área de trabajo con el objetivo de crear y administrar recursos y activos.
#
# Para autenticarse, necesita los valores en tres parámetros necesarios:
#
# - subscription_id: el identificador de suscripción.
# - resource_group: el nombre del grupo de recursos.
# - workspace_name: el nombre del área de trabajo.
# A continuación, puede definir la autenticación mediante el código siguiente:

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient(
    DefaultAzureCredential(), 
    "------------------------------------", # subscription_id
    "----------------------------------",   # resource_group
    "-------------"                         # workspace
)

# I tried with my parameters, you need to use your owner credentials

# %% [markdown]
# Después de definir la autenticación, debe llamar al método MLClient del entorno para conectarse al área de trabajo. Llamará a MLClient cada vez que quiera crear o actualizar un recurso o un recurso en el área de trabajo.
#
# Por ejemplo, se conectará al área de trabajo al crear un nuevo trabajo para entrenar un modelo:

# %%
from azure.ai.ml import command

# configure job
job = command(
    code="./src",
    command="python train.py",
    environment="AzureML-sklearn-0.24-ubuntu18.04-py37-cpu@latest",
    compute="aml-cluster",
    experiment_name="train-model"
)

# connect to workspace and submit job
returned_job = ml_client.create_or_update(job)

# Adapt the code to the specifications and links of the project
